# %% [markdown]
# # Introduction
# State notebook purpose here

# %% [markdown]
# ### Imports
# Import libraries and write settings here.

# %%
# Data manipulation
import pandas as pd
import numpy as np


import os
import requests
from bs4 import BeautifulSoup

# Options for pandas
pd.options.display.max_columns = None
pd.options.display.max_rows = None

pd.options.display.max_colwidth=-1

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

from IPython import get_ipython
ipython = get_ipython()

# autoreload extension
if 'autoreload' not in ipython.extension_manager.loaded:
    # %load_ext autoreload

# %autoreload 2

# Visualizations
import plotly.express as px

# %% [markdown]
# # Analysis/Modeling
# Let us scrap data from https://www.magicbricks.com/Property-Rates-Trends/ALL-RESIDENTIAL-rates-in-Bangalore to get area wise prices in bangalore from 2007 to the latest quarter

# %%
base_url="https://www.magicbricks.com/Property-Rates-Trends/ALL-RESIDENTIAL-rates-in-Bangalore"

# %%
base_url
# Out:
# 'https://www.magicbricks.com/Property-Rates-Trends/ALL-RESIDENTIAL-rates-in-Bangalore'

# %%
response=requests.get(base_url)

# %%
response.content
# Out:
# b'<!doctype html>\n<html>\n<head>\n<script type="text/javascript">\n\n\t\n\tvar context_url = \'/bricks/\';\n\t\tvar domainUrl = \'https://www.magicbricks.com\';\n\t\t//var jsPath = \'https://www.magicbricks.comhttps://cdn.staticmb.com/scripts/\';\n\t\tvar jsPath = \'https://cdn.staticmb.com/scripts/\';\n\t\tvar GOOGLE_MAP_KEY_API_V3 = \'https://maps.googleapis.com/maps/api/js?key=AIzaSyC_YU1YQKR4YoafqUTg2vsoPS1JHqW-pto&sensor=false\';\n\t\tvar SITE_DOMAIN_URL = \'https://www.magicbricks.com/bricks/\';\n\t\tvar POST_PROPERTY_DOMAIN_URL = \'https://post.magicbricks.com/postproperty/\';\n</script>\n<script>\nwindow.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;\nga(\'create\', \'UA-492553-10\', \'auto\');\nga(\'require\', \'ecommerce\');\nga(\'send\', \'pageview\');\n</script>\n<script async src=\'https://www.google-analytics.com/analytics.js\'></script>\n<style type="text/css">\n@font-face {\n    font-family: \'open_sansregular\';\n    src: url(\'https://cdn
# ...
